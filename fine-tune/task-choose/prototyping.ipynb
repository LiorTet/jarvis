# %% [markdown]
# # Phi3 mini QLORA

# %%
import json
import random

# %% [markdown]
# ## Data generation

# %%
ADD_TASK = [
    "Add 'buy milk' to my tasks.",
    "Remind me to finish the report tomorrow.",
    "Tomorrow I need to call my mom.",
    "Schedule writing an email later today.",
    "Can you add 'book a dentist appointment' to my list?",
    "Please remind me to water the plants tomorrow.",
    "Put 'send the contract to Sarah' on my to-do list.",
    "Add 'pick up dry cleaning' as a task for today.",
    "Note that I have to renew my passport next week.",
    "Add to my tasks: call John after lunch.",
    "Put down 'buy groceries' for tonight.",
    "I need to remember to clean the garage this weekend.",
    "Remind me to check the mail tomorrow morning.",
    "Add 'pay the electricity bill' to my list.",
    "Add a task to finish reading the book.",
    "Schedule a meeting with the team for Friday.",
    "Add 'take the car for servicing' to my tasks.",
    "Please remind me to send the invoice by Monday.",
    "Put 'order birthday cake' on my task list.",
    "I want to add 'prepare presentation slides' to my schedule.",
    "Add 'call the bank about the loan' tomorrow.",
    "Remind me to book flight tickets next week.",
    "Add 'submit the assignment' as a new task.",
    "Schedule 'doctor appointment' for next Tuesday.",
    "Please add 'clean the kitchen' to today's tasks.",
    "Can you add 'finish project proposal' to my list?",
    "Add a reminder to check emails after lunch.",
    "Put 'visit the vet' on my tasks for Thursday.",
    "Remind me to pay credit card bill on Friday.",
    "Add 'pick up kids from school' to my schedule.",
    "Add 'send thank-you emails' to my to-do list.",
    "Schedule time to review the budget report.",
    "Add 'buy groceries for dinner' tonight.",
    "Put 'call mom' on my task list for tomorrow.",
    "Remind me to water the garden this weekend.",
    "Add 'finish the quarterly report' by Wednesday.",
    "Please add 'book hotel for conference' to tasks.",
    "Schedule 'gym session' for tomorrow morning.",
    "Add 'email the client the contract' today.",
    "Put 'pay utility bills' on my to-do list.",
    "Remind me to backup my files tonight.",
    "Add 'prepare slides for meeting' to my tasks.",
    "Add 'order office supplies' to my list.",
    "Schedule 'team lunch' on Friday afternoon.",
    "Please add 'call electrician' to my schedule.",
    "Remind me to confirm appointment with dentist.",
    "Add 'send project update' to my task list.",
    "Put 'review resumes' on my tasks for Monday.",
    "Add 'prepare questions for interview' tomorrow.",
    "Add 'buy milk' to my tasks.",
    "Remind me to finish the report tomorrow.",
    "Tomorrow I need to call my mom.",
    "Schedule writing an email later today.",
    "Can you add 'book a dentist appointment' to my list?",
    "Please remind me to water the plants tomorrow.",
    "Put 'send the contract to Sarah' on my to-do list.",
    "Add 'pick up dry cleaning' as a task for today.",
    "Note that I have to renew my passport next week.",
    "Add to my tasks: call John after lunch.",
    "Put down 'buy groceries' for tonight.",
    "I need to remember to clean the garage this weekend.",
    "Remind me to check the mail tomorrow morning.",
    "Add 'pay the electricity bill' to my list.",
    "Add a task to finish reading the book.",
    "Schedule a meeting with the team for Friday.",
    "Add 'take the car for servicing' to my tasks.",
    "Please remind me to send the invoice by Monday.",
    "Put 'order birthday cake' on my task list.",
    "I want to add 'prepare presentation slides' to my schedule.",
    "Add 'call the bank about the loan' tomorrow.",
    "Remind me to book flight tickets next week.",
    "Add 'submit the assignment' as a new task.",
    "Schedule 'doctor appointment' for next Tuesday.",
    "Please add 'clean the kitchen' to today's tasks.",
    "Can you add 'finish project proposal' to my list?",
    "Add a reminder to check emails after lunch.",
    "Put 'visit the vet' on my tasks for Thursday.",
    "Remind me to pay credit card bill on Friday.",
    "Add 'pick up kids from school' to my schedule.",
    "Add 'send thank-you emails' to my to-do list.",
    "Schedule time to review the budget report.",
    "Add 'buy groceries for dinner' tonight.",
    "Put 'call mom' on my task list for tomorrow.",
    "Remind me to water the garden this weekend.",
    "Add 'finish the quarterly report' by Wednesday.",
    "Please add 'book hotel for conference' to tasks.",
    "Schedule 'gym session' for tomorrow morning.",
    "Add 'email the client the contract' today.",
    "Put 'pay utility bills' on my to-do list.",
    "Remind me to backup my files tonight.",
    "Add 'prepare slides for meeting' to my tasks.",
    "Add 'order office supplies' to my list.",
    "Schedule 'team lunch' on Friday afternoon.",
    "Please add 'call electrician' to my schedule.",
    "Remind me to confirm appointment with dentist.",
    "Add 'send project update' to my task list.",
    "Put 'review resumes' on my tasks for Monday.",
    "Add 'prepare questions for interview' tomorrow.",
    "Hey, can you put 'finish my tax forms' on my to-do list?",
    "Don't forget to add 'call the plumber' to my tasks.",
    "Could you please remind me to 'submit my timesheet' by Friday?",
    "Add 'plan birthday party' to my agenda.",
    "I want to add a task for 'fix the leaking faucet' this weekend.",
    "Please schedule 'book a haircut appointment' next week.",
    "Make sure 'send birthday card to Lisa' is on my list.",
    "Add a note to 'pick up prescription' tomorrow morning.",
    "I'd like to add 'finalize budget proposal' to my tasks.",
    "Add 'prepare dinner for guests' on Saturday evening.",
    "Can you set a task for me to 'call insurance company'?",
    "Add 'register for the conference' as an urgent task.",
    "Please remind me to 'check the car tire pressure' later.",
    "Add 'update project documentation' to my to-dos.",
    "Put 'arrange house cleaning' on my schedule for Friday.",
    "Schedule a reminder to 'pay the rent' by the 1st of next month.",
    "Add 'finish writing blog post' to my tasks today.",
    "Make a note to 'follow up with the recruiter' tomorrow.",
    "Please add 'prepare slides for the keynote' this week.",
    "Add 'buy tickets for the concert' as a priority.",
    "Set a reminder to 'send the presentation draft' by noon.",
    "Add 'organize files on desktop' to my to-do list.",
    "Put down 'call grandma' in my tasks for the weekend.",
    "Schedule a task to 'renew gym membership' next month.",
    "Please add 'clean out the fridge' to my chores.",
    "Add 'order new business cards' before Friday.",
    "Add a reminder to 'book hotel room' for the business trip.",
    "Put 'finalize quarterly financial report' on my work list.",
    "Make sure 'send thank-you notes' are on my agenda.",
    "Add 'meet with marketing team' next Tuesday.",
    "Please add 'prepare client proposal' to my task list.",
    "Add 'submit expense report' by the end of this week.",
    "Set task for 'review legal documents' tomorrow afternoon.",
    "Add 'buy groceries' for the weekend.",
    "Don't forget to add 'pack for the trip' on Thursday.",
    "Please add a task: 'schedule dentist check-up'.",
    "Add 'call the electrician' this evening.",
    "Schedule 'team retrospective meeting' for next Wednesday.",
    "Put 'send follow-up email to Sarah' on my list.",
    "Add 'prepare notes for the workshop' by Friday.",
    "Add 'book table at restaurant' for Saturday night.",
    "Add 'update LinkedIn profile' as a new task.",
    "Add a task to 'finish watching the tutorial videos'.",
    "Put down 'prepare tax documents' for next Monday.",
    "Add 'call the vet for vaccination appointment'.",
    "Please schedule 'pay credit card minimum' before due date.",
    "Add 'confirm hotel reservation' for the conference.",
    "Remind me to 'submit my passport renewal form'.",
    "Add a note to 'follow up on job application'.",
    "Add 'prepare questions for the team meeting'.",
    "Put 'schedule car maintenance' on my calendar.",
    "Add 'write thank you email to client' to my list.",
    "Please add 'backup laptop data' to my tasks.",
    "Add 'set up a meeting with HR' next week.",
    "Schedule 'check inventory' for Thursday morning.",
    "Add 'buy birthday gift for Anna' on my task list.",
    "Add a task for 'update website content' today.",
    "Put 'submit project milestones' on my to-do list.",
    "Add 'prepare financial presentation' for Monday.",
    "Add 'renew subscription to the magazine'.",
    "Please remind me to 'call the bank about the credit card'.",
    "Add 'finish drafting the email newsletter'.",
    "Add 'review and sign contract' by end of day.",
    "Put 'send monthly report to the manager' on my list.",
    "Add 'schedule annual health check-up'.",
    "Please add 'plan weekend getaway' to my tasks.",
    "Add 'organize team-building event' next month.",
    "Add a task: 'review customer feedback survey'.",
    "Put 'write blog post on AI advancements' on my agenda.",
    "Add 'update software licenses' before expiry.",
    "Add 'prepare for the client presentation' next week."
]

# %%
LIST_TASKS = [
    "What do I have to do?",
    "Show me my tasks.",
    "List my tasks for tomorrow.",
    "Can you tell me what’s on my to-do list?",
    "What tasks do I have scheduled?",
    "Do I have any tasks today?",
    "Give me a list of my current tasks.",
    "What’s on my agenda?",
    "Please list all my pending tasks.",
    "Can you show my tasks for the week?",
    "What reminders do I have?",
    "Tell me what’s left to do.",
    "List the tasks I have for today.",
    "Do I have any upcoming tasks?",
    "Show all my to-dos.",
    "What’s on my task list?",
    "Can you display my tasks?",
    "Give me the list of tasks I need to complete.",
    "What’s on my schedule?",
    "Tell me my next tasks.",
    "Show me all pending tasks.",
    "What tasks are planned for tomorrow?",
    "Do I have anything to work on this week?",
    "List the chores I need to do.",
    "What assignments are due soon?",
    "Show me the tasks I haven’t finished yet.",
    "Can you remind me of my tasks?",
    "What’s next on my to-do list?",
    "Tell me all my current tasks.",
    "Show me the tasks for this afternoon.",
    "What do I need to get done today?",
    "Give me my list of assignments.",
    "List my outstanding tasks.",
    "What tasks are scheduled for Monday?",
    "Do I have any tasks left for today?",
    "Show my tasks for the weekend.",
    "Can you display what I need to do next?",
    "Give me all my to-dos for this month.",
    "What tasks are on my plate?",
    "Tell me about my pending jobs.",
    "List the things I have to do.",
    "Show all upcoming tasks.",
    "What tasks have I planned for next week?",
    "What do I need to accomplish today?",
    "List the tasks on my calendar.",
    "Can you show me what’s due soon?",
    "Give me a rundown of my tasks.",
    "What are my pending assignments?",
    "What tasks should I focus on?",
    "Tell me the tasks I need to handle.",
    "Show the list of things I need to do.",
    "Do I have any important tasks coming up?",
    "List my daily tasks.",
    "What tasks do I have this afternoon?",
    "Show my to-do list for tomorrow.",
    "What do I have scheduled this week?",
    "Give me all tasks for today.",
    "Tell me the tasks planned for next month.",
    "Show my unfinished tasks.",
    "Can you list the things I need to remember?",
    "What’s on my workload?",
    "List all my upcoming deadlines.",
    "Tell me about my tasks due today.",
    "Show all tasks for the morning.",
    "What’s on my action list?",
    "Give me a summary of my tasks.",
    "What needs to be done this week?",
    "Show my tasks for Friday.",
    "List the chores I planned for this weekend.",
    "Do I have any tasks I missed?",
    "What’s on my task agenda?",
    "Show the tasks I added recently.",
    "What do I have to complete tomorrow?",
    "List my scheduled reminders.",
    "Give me an overview of my tasks.",
    "What jobs do I have this month?",
    "Can you show my task list?",
    "Tell me what’s left on my to-do list.",
    "What are the tasks I’ve planned for today?",
    "List all tasks assigned to me.",
    "Show my important tasks.",
    "What do I have to take care of?",
    "Give me all tasks for the week ahead.",
    "Show me the list of tasks I’ve created.",
    "What’s on my checklist?",
    "List all pending tasks for today.",
    "What assignments are due tomorrow?",
    "Show my task list for next week.",
    "What do I need to prepare for tomorrow?",
    "Can you tell me my remaining tasks?",
    "List the things I have scheduled for today.",
    "Show me the jobs I need to do.",
    "What’s on my work list?",
    "Give me the tasks I set for this week.",
    "Show all my scheduled tasks.",
    "What do I need to follow up on?",
    "List the tasks I marked as important.",
    "What are my top priority tasks?",
    "Show my tasks for this evening.",
    "What’s left to complete on my list?",
    "Tell me all the tasks due soon.",
    "List the things I need to get done this month.",
    "What do I have planned for tomorrow afternoon?",
    "Show my urgent tasks.",
    "Can you list all my reminders?",
    "Tell me what’s on my to-do agenda today.",
]

# %%
DELETE_TASKS = [
    "Delete my task.",
    "Remove this task from my list.",
    "Can you delete the task I just added?",
    "I want to delete a task.",
    "Please remove the task about the meeting.",
    "Delete the reminder for tomorrow.",
    "Get rid of the task I completed.",
    "Remove the task due next week.",
    "Delete my to-do item.",
    "Erase that task from my schedule.",
    "Can you take out the task I no longer need?",
    "Delete the assignment I finished.",
    "Remove the chore I just completed.",
    "Delete the task for Friday.",
    "Please delete the task titled 'Buy groceries'.",
    "Remove the event from my to-do list.",
    "I want to get rid of the task about the report.",
    "Delete the task I marked as urgent.",
    "Remove the job I no longer want to do.",
    "Delete the task scheduled for tomorrow morning.",
    "Can you delete the pending task about the call?",
    "Delete my old tasks.",
    "Remove the task I added yesterday.",
    "Please delete the reminder for the dentist appointment.",
    "Delete all completed tasks.",
    "Can you erase the task for the project deadline?",
    "Remove the task from my daily list.",
    "Delete the reminder I set for this afternoon.",
    "Delete the task about sending the email.",
    "Remove the task on my agenda.",
    "Delete the task related to my homework.",
    "I want to delete all tasks for today.",
    "Delete the task I’m no longer interested in.",
    "Remove the task for the team meeting.",
    "Please delete the to-do about the birthday gift.",
    "Delete the scheduled task for next week.",
    "Erase the task I completed last night.",
    "Delete the job from my to-do list.",
    "Remove the task about updating the document.",
    "Delete the task assigned to me.",
    "Can you delete the reminder I set this morning?",
    "Remove the task with the deadline on Monday.",
    "Delete the event I just added.",
    "Erase that reminder from my list.",
    "Delete the task I don’t want anymore.",
    "Please remove the task about the gym.",
    "Delete the task on my calendar for Friday.",
    "Delete the urgent task from my list.",
    "Remove the task I marked as low priority.",
    "Delete the reminder for the conference call.",
    "Can you remove the task about the presentation?",
    "Delete the task I forgot to finish.",
    "Remove the task scheduled for this weekend.",
    "Delete the note I attached to that task.",
    "Delete the task labeled 'Follow up with client'.",
    "Please erase the task about the software update.",
    "Delete the task I cancelled.",
    "Remove all tasks I completed last week.",
    "Delete the reminder for tomorrow’s appointment.",
    "Erase the task about the monthly report.",
    "Delete the task I no longer need to do.",
    "Remove the task from my to-do list.",
    "Delete that task.",
    "Can you delete the latest task?",
    "Please delete all outdated tasks.",
    "Remove the task I don’t want to see.",
    "Delete the job related to the office move.",
    "Erase the task that was due yesterday.",
    "Delete the scheduled reminder.",
    "Remove the task from my pending list.",
    "Delete the task about the invoice.",
    "Please delete the task I finished earlier.",
]

# %%
UNRELATED_TASKS = [
    "What’s the weather like today?",
    "Tell me a joke.",
    "Play some music.",
    "How’s the stock market doing?",
    "What time is it in Tokyo?",
    "Can you set an alarm for 7 AM?",
    "Translate ‘hello’ to Spanish.",
    "Show me pictures of cats.",
    "Who won the game last night?",
    "Find nearby restaurants.",
    "How do I bake a chocolate cake?",
    "Tell me the news headlines.",
    "What movies are playing this weekend?",
    "Turn on the living room lights.",
    "How tall is Mount Everest?",
    "Convert 100 dollars to euros.",
    "Set a timer for 10 minutes.",
    "Tell me about the history of Rome.",
    "Open my calendar app.",
    "What’s the capital of Australia?",
    "Find me a good book to read.",
    "How do I get to the nearest gas station?",
    "Recommend a restaurant nearby.",
    "What’s the meaning of life?",
    "Sing me a song.",
    "How far is the moon from Earth?",
    "What’s the traffic like downtown?",
    "Can you tell me a fun fact?",
    "What’s the recipe for lasagna?",
    "Who is the president of France?",
    "Tell me a story.",
    "What are the symptoms of the flu?",
    "How do I fix a leaking faucet?",
    "Show me the latest sports scores.",
    "Can you solve this math problem?",
    "What’s the latest tech news?",
    "Help me learn French.",
    "Tell me a riddle.",
    "How do I change a tire?",
    "What’s the tallest building in the world?",
    "What are some good workout routines?",
    "Who wrote ‘To Kill a Mockingbird’?",
    "How do I meditate?",
    "Find flights to New York.",
    "What’s the best way to learn coding?",
    "Tell me about the solar system.",
    "Can you remind me to drink water?",
    "What is the meaning of ‘serendipity’?",
    "Show me directions to the nearest hospital.",
    "What’s the latest on climate change?",
    "Who won the Nobel Prize in Literature last year?",
]

# %%
COMMANDS = {
    "ADD_TASK": ADD_TASK,
    "LIST_TASKS": LIST_TASKS,
    "CLEAR_TASKS": DELETE_TASKS,
    "UNRELATED": UNRELATED_TASKS
}

# %%
def generate_classification_dataset(commands):
    """
    Generate a classification dataset with 'text' and 'label' keys.
    Returns a shuffled list of dicts, each with user input and corresponding label.
    """
    data = []
    for label, examples in commands.items():
        for text in examples:
            data.append({"text": text, "label": label})
    random.shuffle(data)
    return data

# %%
dataset = generate_classification_dataset(commands=COMMANDS)

# %%
dataset[:10]
# Out:
# [{'text': 'Schedule writing an email later today.', 'label': 'ADD_TASK'},
#  {'text': 'Set a timer for 10 minutes.', 'label': 'UNRELATED'},
#  {'text': "Schedule 'gym session' for tomorrow morning.", 'label': 'ADD_TASK'},
#  {'text': 'List all tasks assigned to me.', 'label': 'LIST_TASKS'},
#  {'text': "Don't forget to add 'pack for the trip' on Thursday.",
#   'label': 'ADD_TASK'},
#  {'text': 'What do I need to get done today?', 'label': 'LIST_TASKS'},
#  {'text': 'What do I need to prepare for tomorrow?', 'label': 'LIST_TASKS'},
#  {'text': 'Delete the reminder for tomorrow’s appointment.',
#   'label': 'CLEAR_TASKS'},
#  {'text': 'Find me a good book to read.', 'label': 'UNRELATED'},
#  {'text': 'Remove the task about updating the document.',
#   'label': 'CLEAR_TASKS'}]

# %%
from setfit import SetFitModel, SetFitTrainer
from sklearn.model_selection import train_test_split

# %%
from datasets import Dataset  # Hugging Face datasets

# %%
# Prepare raw data
texts = [item['text'] for item in dataset]
labels = [item['label'] for item in dataset]

# Split into train/test sets
train_texts, test_texts, train_labels, test_labels = train_test_split(
    texts, labels, test_size=0.2, random_state=42, stratify=labels
)

# Convert to Hugging Face Dataset objects
train_dataset = Dataset.from_dict({"text": train_texts, "label": train_labels})
eval_dataset = Dataset.from_dict({"text": test_texts, "label": test_labels})

# Load base model
model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-MiniLM-L6-v2")

# Create the trainer using Hugging Face Datasets
trainer = SetFitTrainer(
    model=model,
    train_dataset=train_dataset,
    eval_dataset=eval_dataset,
    batch_size=16,
    num_iterations=20,
    num_epochs=1,
)

print("Start training")
trainer.train()

metrics = trainer.evaluate()
print(metrics)

trainer.model.save_pretrained("setfit-finetuned-command-classifier")
# Out:
# model_head.pkl not found on HuggingFace Hub, initialising classification head with random weights. You should TRAIN this model on a downstream task to use it for predictions and inference.
# C:\Users\Lior\AppData\Local\Temp\ipykernel_23932\2305752477.py:18: DeprecationWarning: `SetFitTrainer` has been deprecated and will be removed in v2.0.0 of SetFit. Please use `Trainer` instead.
#   trainer = SetFitTrainer(
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[56], line 18
#      15 model = SetFitModel.from_pretrained("sentence-transformers/paraphrase-MiniLM-L6-v2")
#      17 # Create the trainer using Hugging Face Datasets
# ---> 18 trainer = SetFitTrainer(
#      19     model=model,
#      20     train_dataset=train_dataset,
#      21     eval_dataset=eval_dataset,
#      22     batch_size=16,
#      23     num_iterations=20,
#      24     num_epochs=1,
#      25 )
# ...
